# %% [markdown]
# ## **Introduction to Seaborn**
# It is a Python data visualization library based on Matplotlib that provides a high-level interface for creating informative and attractive statistical graphics.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ### **Loading the Dataset**

# %%
df = sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# #### **Exploring Data**

# %%
df.head(15)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2

# %%
df.tail(15)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 233       10.77  1.47    Male     No   Sat  Dinner     2
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
print(df.head(5))
print(df.tail(5))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.shape
# Out:
# (244, 7)

# %%
df.size
# Out:
# 1708

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.describe(include='all')
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df[['day', 'tip']]
# Out:
#       day   tip
# 0     Sun  1.01
# 1     Sun  1.66
# 2     Sun  3.50
# 3     Sun  3.31
# 4     Sun  3.61
# ..    ...   ...
# 239   Sat  5.92
# 240   Sat  2.00
# 241   Sat  2.00
# 242   Sat  1.75
# 243  Thur  3.00
#
# [244 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df[10:21]     # Slicing specific rows
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# 16       10.33  1.67  Female     No  Sun  Dinner     3
# 17       16.29  3.71    Male     No  Sun  Dinner     3
# 18       16.97  3.50  Female     No  Sun  Dinner     3
# 19       20.65  3.35    Male     No  Sat  Dinner     3
# 20       17.92  4.08    Male     No  Sat  Dinner     2

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df[df.duplicated()]
# Out:
#      total_bill  tip     sex smoker   day   time  size
# 202        13.0  2.0  Female    Yes  Thur  Lunch     2

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [243 rows x 7 columns]

# %%
df.reset_index(inplace=True)
df
# Out:
#      level_0  index  total_bill   tip     sex smoker   day    time  size
# 0          0      0       16.99  1.01  Female     No   Sun  Dinner     2
# 1          1      1       10.34  1.66    Male     No   Sun  Dinner     3
# 2          2      2       21.01  3.50    Male     No   Sun  Dinner     3
# 3          3      3       23.68  3.31    Male     No   Sun  Dinner     2
# 4          4      4       24.59  3.61  Female     No   Sun  Dinner     4
# ..       ...    ...         ...   ...     ...    ...   ...     ...   ...
# 238      238    239       29.03  5.92    Male     No   Sat  Dinner     3
# 239      239    240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 240      240    241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 241      241    242       17.82  1.75    Male     No   Sat  Dinner     2
# 242      242    243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [243 rows x 9 columns]

# %%
df.drop(columns=['level_0', 'index'], inplace=True)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 238       29.03  5.92    Male     No   Sat  Dinner     3
# 239       27.18  2.00  Female    Yes   Sat  Dinner     2
# 240       22.67  2.00    Male    Yes   Sat  Dinner     2
# 241       17.82  1.75    Male     No   Sat  Dinner     2
# 242       18.78  3.00  Female     No  Thur  Dinner     2
#
# [243 rows x 7 columns]

# %%
df[df['size'] > 4]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 125       29.80  4.20  Female     No  Thur   Lunch     6
# 141       34.30  6.70    Male     No  Thur   Lunch     6
# 142       41.19  5.00    Male     No  Thur   Lunch     5
# 143       27.05  5.00  Female     No  Thur   Lunch     6
# 155       29.85  5.14  Female     No   Sun  Dinner     5
# 156       48.17  5.00    Male     No   Sun  Dinner     6
# 185       20.69  5.00    Male     No   Sun  Dinner     5
# 187       30.46  2.00    Male    Yes   Sun  Dinner     5
# 215       28.15  3.00    Male    Yes   Sat  Dinner     5

# %%
df['size'].sort_values(ascending=False)
# Out:
# 156    6
# 143    6
# 141    6
# 125    6
# 185    5
#       ..
# 105    2
# 67     1
# 221    1
# 111    1
# 82     1
# Name: size, Length: 243, dtype: int64

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 238       29.03  5.92    Male     No   Sat  Dinner     3
# 239       27.18  2.00  Female    Yes   Sat  Dinner     2
# 240       22.67  2.00    Male    Yes   Sat  Dinner     2
# 241       17.82  1.75    Male     No   Sat  Dinner     2
# 242       18.78  3.00  Female     No  Thur  Dinner     2
#
# [243 rows x 7 columns]

# %%
df.groupby('smoker')['size'].count()
# Out:
# smoker
# Yes     92
# No     151
# Name: size, dtype: int64

# %%
df.groupby('sex')['smoker'].count()
# Out:
# sex
# Male      157
# Female     86
# Name: smoker, dtype: int64

# %%
df['total_bill'].sum()
# Out:
# np.float64(4814.77)

# %%
df.groupby(['sex', 'smoker'])['total_bill'].sum()
# Out:
# sex     smoker
# Male    Yes       1337.07
#         No        1919.75
# Female  Yes        580.27
#         No         977.68
# Name: total_bill, dtype: float64

# %%
df['tip'].sum()
# Out:
# np.float64(729.5799999999999)

# %%
df.groupby(['sex', 'smoker']).agg({'tip':'sum', 'total_bill':'sum'}).reset_index()
# Out:
#       sex smoker     tip  total_bill
# 0    Male    Yes  183.07     1337.07
# 1    Male     No  302.00     1919.75
# 2  Female    Yes   96.74      593.27
# 3  Female     No  149.77      977.68

# %%
df.groupby(['day', 'sex']).agg({'tip':'sum', 'total_bill':'sum'}).reset_index()
# Out:
#     day     sex     tip  total_bill
# 0  Thur    Male   89.41      561.44
# 1  Thur  Female   82.42      534.89
# 2   Fri    Male   26.93      198.57
# 3   Fri  Female   25.03      127.31
# 4   Sat    Male  181.95     1227.35
# 5   Sat  Female   78.45      551.05
# 6   Sun    Male  186.78     1269.46
# 7   Sun  Female   60.61      357.70

# %%
df.groupby(['day', 'sex'])['tip'].sum()
# Out:
# day   sex
# Thur  Male       89.41
#       Female     82.42
# Fri   Male       26.93
#       Female     25.03
# Sat   Male      181.95
#       Female     78.45
# Sun   Male      186.78
#       Female     60.61
# Name: tip, dtype: float64

# %%
df.groupby('day')['smoker'].count()
# Out:
# day
# Thur    62
# Fri     19
# Sat     87
# Sun     76
# Name: smoker, dtype: int64

# %%
df.loc[1, 'smoker']
# Out:
# 'No'

# %%
df.loc[15, 'total_bill']
# Out:
# np.float64(21.58)

# %%
df.loc[11]
# Out:
# total_bill     35.26
# tip              5.0
# sex           Female
# smoker            No
# day              Sun
# time          Dinner
# size               4
# Name: 11, dtype: object

# %%
df.iloc[123]
# Out:
# total_bill    15.95
# tip             2.0
# sex            Male
# smoker           No
# day            Thur
# time          Lunch
# size              2
# Name: 123, dtype: object

# %%
df.groupby('time')['smoker'].count()
# Out:
# time
# Lunch      67
# Dinner    176
# Name: smoker, dtype: int64

# %%
df['total_bill'].mean()
# Out:
# np.float64(19.813868312757204)

# %%
# Gender Analysis
gender_analysis = df.groupby('sex')[['total_bill', 'tip']].mean()
print('\nGender Analysis:\n', gender_analysis)
# Out:
# Gender Analysis:
#          total_bill       tip
# sex
# Male     20.744076  3.089618
# Female   18.056897  2.833448

# %%
# Time Analysis
time_analysis = df.groupby('time')[['total_bill', 'tip']].mean()
print('\nTime Analysis:\n', time_analysis)
# Out:
# Time Analysis:
#          total_bill       tip
# time
# Lunch    17.168676  2.728088
# Dinner   20.797159  3.102670

# %%
cross_tab = pd.crosstab(index=[df['sex']],
                        columns=[df['time']])
cross_tab
# Out:
# time    Lunch  Dinner
# sex
# Male       33     124
# Female     34      52

# %% [markdown]
# ### **Data Visualization using Seaborn**
# #### **1. Bar Plot/ Count Plot**
# - Displaying the distribution of categorical variables.
# - Visualizing the frequency or count of each category in a dataset.

# %%
df.groupby('day')['tip'].sum()
# Out:
# day
# Thur    171.83
# Fri      51.96
# Sat     260.40
# Sun     247.39
# Name: tip, dtype: float64

# %%
ac = sns.barplot(data=df, x='day', y='tip', estimator='mean', errorbar=None)
ac.bar_label(ac.containers[0], fontsize=10)
ac.plot('Sun', 3.5, 'r*', markersize=10)
plt.grid()
plt.xlabel('Days')
plt.ylabel('Tips')
plt.title('Bar Plot of Tips by Days')
plt.show()

# %% [markdown]
# #### **2. Count Plot**
# - Shows the count of observations in each categorical bin using bars.

# %%
sns.countplot(data=df, x='day', hue='smoker', palette='Greens')
plt.grid(True)
plt.title('Count of Tips by Days')
plt.show()

# %% [markdown]
# #### **3. Pie Chart**

# %%
Smoker = df['smoker'].value_counts()
Smoker
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
plt.pie(Smoker, labels=Smoker.index, autopct='%1.f%%', explode=[0, 0.1], colors=sns.color_palette('Set1'))
plt.legend()
plt.title('Distribution of Smoker')
plt.show()

# %%
sns.color_palette('summer')
# Out:
# [(0.1411764705882353, 0.5705882352941176, 0.4),
#  (0.28627450980392155, 0.6431372549019607, 0.4),
#  (0.42745098039215684, 0.7137254901960784, 0.4),
#  (0.5725490196078431, 0.7862745098039216, 0.4),
#  (0.7137254901960784, 0.8568627450980393, 0.4),
#  (0.8588235294117647, 0.9294117647058824, 0.4)]

# %% [markdown]
# #### **4. Scatter Plot**
# - Exploring the relationship between two continuous variables.
# - Identifying patterns, correlations, or in the data.

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
sns.scatterplot(data=df, x='total_bill', y='tip', alpha=0.5, marker='*', edgecolor='black', legend=True, size='size', sizes=(20, 200))
plt.title('Scatter Plot of Total Bill by Tips')
plt.show()

# %% [markdown]
# #### **5. Line Plot**
# - Displaying the trend or pattern in a time series.
# - Showing the relationship between two continuous variables over a continuous inerval.
# - Comparing changes in variables over a continuous range.

# %%
sns.lineplot(data=df, x='day', y='tip', hue='sex', orient='x', marker='*', markersize=10, linestyle=':')
plt.title('Line Plot of Tip over Total_bill')
plt.show()

# %% [markdown]
# #### **6. Box Plot**
# - Displaying the mean, median, quantiles, and outliers in the data.
# - Comparing the distribution of multiple variables.
# - Identifying the spread of numerical variables.
# - Detecting potential outliers in the dataset.

# %%
sns.boxplot(data=df, y='total_bill', fill=True, palette='Set3')
plt.title('Box Plot of Total Bill')
plt.show()

# %% [markdown]
# #### **7. Density Plot**
# - Visualizing the distribution of a continuous variable.
# - Identifying the peaks, valeeys, and overall patterns in the data.
# - Understanding the shape of the distribution.
# - Comparing the distributions of multiple variables.

# %%
sns.distplot(df['total_bill'], hist=True, bins=20, color='b', kde=True, vertical=False)
plt.title("Distribution Plot of Total Bill")
plt.show()

# %%
sns.kdeplot(data=df, x='total_bill', hue='time', shade=True)
plt.title('Kernel Density Estimation Plot of Total Bill')
plt.show()

# %%
sns.histplot(data=df, x='total_bill', edgecolor='black', bins=10, element='step', color='blue')
plt.title('Hist Plot of Total Bill')
plt.show()

# %% [markdown]
# #### **8. Pair Plot**
# Exploring correlations and trends between multiple variables by visualizing them in pairs.

# %%
sns.pairplot(df, kind='scatter')
#sns.pairplot(df, hue='time', diag_kind='hist')
plt.suptitle("Pair Plot of Numerical variables by day", y=1.02, x=0.5)
plt.show()

# %%
#sns.pairplot(df, kind='scatter')
sns.pairplot(df, hue='time', diag_kind='hist')
plt.suptitle("Pair Plot of Numerical variables by day", y=1.02, x=0.5)
plt.show()

# %% [markdown]
# #### **9. Heatmap**
# - Displaying the correlation matrix of numerical variables.
# - Identifying patterns and relationships in a large dataset.

# %%
Num = df.select_dtypes(include=['int', 'float']).columns.tolist()
Num
# Out:
# ['total_bill', 'tip', 'size']

# %%
correlation_matrix = df[Num].corr()
correlation_matrix
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='PuBu')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# #### **10. Violin Plot**
# - Combines the features of box plots and kernel density plots.
# - Visualizing the distribution of a numerical variable across different categories.

# %%
sns.violinplot(data=df, y='total_bill', split=False, inner_kws=dict(box_width=15, whis_width=2), palette='Set3')
plt.title('Violin Plot of Total Bill by Days', color='blue', fontsize=16, fontweight='bold')
plt.show()

# %%
sns.violinplot(data=df, x='day', y='total_bill', split=False, inner_kws=dict(box_width=15, whis_width=2), palette='Set3')
plt.title('Violin Plot of Total Bill by Days', color='blue', fontsize=16, fontweight='bold')
plt.show()

# %% [markdown]
# #### **11. Join Plot**
# - Exploring the relationship between two continuous variables.
# - Identifying the patterns, correlations, or clusters in the data.

# %%
x = 'total_bill'
y = 'tip'
sns.jointplot(x=x, y=y, kind='scatter', data=df, color='red')    # scatter  | kde | hist | hex | reg | resid 
plt.show()

# %% [markdown]
# #### **12. Swarm Plot**
# - Draws a categorical scatterplot with points adjusted to be non-overlapping.
# - This function is similar to stripplot(), but the points are adjusted (only along the categorical axis) so that they don't overlap.

# %%
sns.set_style('whitegrid')
# Create a swarmplot
sns.swarmplot(x='day', y='total_bill', hue='size', data=df, size=10, legend=True, marker='*')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# #### **13. Strip Plot**
# - Draw a categorical scatterplot using jitter to reduce overplotting.
# - A Strip plot can be drawn on its own, but it is also a good complement to a box or violin plot in cases where you want to show all observations along with some representation of the underlying distribution.

# %%
sns.set(font_scale=1)
sns.stripplot(data=df, x='day', y='total_bill', hue='smoker', size=10)
plt.show()

# %% [markdown]
# #### **14. SubPlots**

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2,2,1)
sns.barplot(data=df, x='sex', y='tip', hue='day', color='lightgreen', errorbar=None, legend=False)
plt.title('Line Plot of Smoker by Tips')

plt.subplot(2,2,2)
sns.scatterplot(data=df, x='size', y='total_bill', color='green', edgecolor='black', marker='o')
plt.title('Bar Plot of Total bill by size')

plt.subplot(2,2,3)
sns.boxplot(data=df, y='tip', color='green')
plt.title('Box Plot of Tip')

plt.subplot(2,2,4)
sns.histplot(data=df, x='size', color='green')
plt.title('Hist Plot of Size')

plt.tight_layout()
plt.show()

# %%
sns.color_palette('Greens')
# Out:
# [(0.8828143021914648, 0.9546943483275664, 0.8621914648212226),
#  (0.7371472510572856, 0.895517108804306, 0.7108342945021145),
#  (0.5573241061130334, 0.8164244521337947, 0.546958861976163),
#  (0.3388235294117647, 0.7117262591311034, 0.40584390618992694),
#  (0.17139561707035755, 0.581514801999231, 0.2979008073817762),
#  (0.017762399077277974, 0.44267589388696654, 0.18523644752018453)]
